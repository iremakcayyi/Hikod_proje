# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('astronauts.csv')

# %%
df.head()
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired   3/3/1946     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired  5/20/1951  St. Louis, MO   Male
# 4       Buzz Aldrin  1963.0    3.0  Retired  1/20/1930  Montclair, NJ   Male
#
#                                           Alma Mater     Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...                 Geology
# 1   Montana State University; University of Colorado     Engineering Physics
# 2          US Military Academy; Princeton University             Engineering
# 3                       University of Missouri-Rolla     Applied Mathematics
# 4                           US Military Academy; MIT  Mechanical Engineering
#
# ...

# %%
df.tail()
# Out:
#                       Name    Year  Group   Status Birth Date  \
# 352          David A. Wolf  1990.0   13.0  Retired  8/23/1956
# 353  Neil W. Woodward III   1998.0   17.0  Retired  7/26/1962
# 354       Alfred M. Worden  1966.0    5.0  Retired   2/7/1932
# 355          John W. Young  1962.0    2.0  Retired  9/24/1930
# 356        George D. Zamka  1998.0   17.0  Retired  6/29/1962
#
#            Birth Place Gender  \
# 352   Indianapolis, IN   Male
# 353        Chicago, IL   Male
# 354        Jackson, MI   Male
# 355  San Francisco, CA   Male
# 356    Jersey City, NJ   Male
#
#                                             Alma Mater  \
# 352              Purdue University; Indiana University
# 353  MIT; University of Texas-Austin; George Washin...
# 354        US Military Academy; University of Michigan
# 355                    Georgia Institute of Technology
# 356  US Naval Academy; Florida Institute of Technology
#
# ...

# %%
print("Number of records:", len(df))
# Out:
# Number of records: 357

# %%
print("Unique values per column:")
for column in df.columns:
    print(column, ":", df[column].nunique())
# Out:
# Unique values per column:
# Name : 357
# Year : 20
# Group : 20
# Status : 4
# Birth Date : 348
# Birth Place : 272
# Gender : 2
# Alma Mater : 280
# Undergraduate Major : 83
# Graduate Major : 143
# Military Rank : 12
# Military Branch : 14
# Space Flights : 8
# Space Flight (hr) : 270
# Space Walks : 11
# Space Walks (hr) : 52
# Missions : 305
# Death Date : 38
# Death Mission : 3

# %% [markdown]
# Sütun başına benzersiz değerler:
# İsim : 357
# Yıl : 20
# Grup : 20
# Durum : 4
# Doğum Tarihi : 348
# Doğum Yeri : 272
# Cinsiyet : 2
# Mezun olunan okul : 280
# Lisans Anadal : 83
# Yüksek Lisans Anadal : 143
# Askeri Rütbe : 12
# Askeri Şube : 14
# Uzay Uçuşları : 8
# Uzay Uçuşu (saat): 270
# Uzay Yürüyüşleri : 11
# Uzay Yürüyüşleri (saat): 52
# Görevler : 305
# Ölüm Tarihi : 38
# Ölüm Görevi : 3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 357 non-null    object
#  1   Year                 330 non-null    float64
#  2   Group                330 non-null    float64
#  3   Status               357 non-null    object
#  4   Birth Date           357 non-null    object
#  5   Birth Place          357 non-null    object
#  6   Gender               357 non-null    object
#  7   Alma Mater           356 non-null    object
#  8   Undergraduate Major  335 non-null    object
#  9   Graduate Major       298 non-null    object
#  10  Military Rank        207 non-null    object
#  11  Military Branch      211 non-null    object
#  12  Space Flights        357 non-null    int64
#  13  Space Flight (hr)    357 non-null    int64
#  14  Space Walks          357 non-null    int64
# ...

# %%
df.describe().T
# Out:
#                    count         mean          std     min     25%     50%  \
# Year               330.0  1985.106061    13.216147  1959.0  1978.0  1987.0
# Group              330.0    11.409091     5.149962     1.0     8.0    12.0
# Space Flights      357.0     2.364146     1.428700     0.0     1.0     2.0
# Space Flight (hr)  357.0  1249.266106  1896.759857     0.0   289.0   590.0
# Space Walks        357.0     1.246499     2.056989     0.0     0.0     0.0
# Space Walks (hr)   357.0     7.707283    13.367973     0.0     0.0     0.0
#
#                       75%      max
# Year               1996.0   2009.0
# Group                16.0     20.0
# Space Flights         3.0      7.0
# Space Flight (hr)  1045.0  12818.0
# Space Walks           2.0     10.0
# Space Walks (hr)     12.0     67.0

# %%
df.isnull().any()
# Out:
# Name                   False
# Year                    True
# Group                   True
# Status                 False
# Birth Date             False
# Birth Place            False
# Gender                 False
# Alma Mater              True
# Undergraduate Major     True
# Graduate Major          True
# Military Rank           True
# Military Branch         True
# Space Flights          False
# Space Flight (hr)      False
# Space Walks            False
# Space Walks (hr)       False
# Missions                True
# Death Date              True
# Death Mission           True
# dtype: bool

# %%
print("Missing values per column:")
print(df.isnull().sum())
# Out:
# Missing values per column:
# Name                     0
# Year                    27
# Group                   27
# Status                   0
# Birth Date               0
# Birth Place              0
# Gender                   0
# Alma Mater               1
# Undergraduate Major     22
# Graduate Major          59
# Military Rank          150
# Military Branch        146
# Space Flights            0
# Space Flight (hr)        0
# Space Walks              0
# Space Walks (hr)         0
# Missions                23
# Death Date             305
# Death Mission          341
# dtype: int64

# %%
df.head()
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired   3/3/1946     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired  5/20/1951  St. Louis, MO   Male
# 4       Buzz Aldrin  1963.0    3.0  Retired  1/20/1930  Montclair, NJ   Male
#
#                                           Alma Mater     Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...                 Geology
# 1   Montana State University; University of Colorado     Engineering Physics
# 2          US Military Academy; Princeton University             Engineering
# 3                       University of Missouri-Rolla     Applied Mathematics
# 4                           US Military Academy; MIT  Mechanical Engineering
#
# ...

# %%
df["Undergraduate Major"].unique()
# Out:
# array(['Geology', 'Engineering Physics', 'Engineering',
#        'Applied Mathematics', 'Mechanical Engineering',
#        'Mathematics & Physics',
#        'Aeronautical & Astronautical Engineering', 'Nuclear Engineering',
#        'Physics', 'Physics & Astronomy', 'Aeronautics & Astronautics',
#        'Aeronautical Engineering', 'Accounting', 'Electrical Engineering',
#        'Aerospace Engineering', 'Zoology',
#        'Physics & Mechanical Engineering', 'Engineering Science',
#        'Engineering Mechanics', nan, 'Electrical Science',
#        'Business Management; Aeronautical Engineering', 'Mathematics',
#        'Biology', 'Biochemistry', 'Chemistry',
#        'Aerospace Engineering & Mechanics', 'Physics & Mathematics',
#        'Chemical Engineering', 'Biological Science',
#        'Mathematics & Economics',
#        'Applied Biology; Mechanical Engineering',
#        'Chemistry; Physiological Optics',
#        'Physics & Astronautical Engineering', 'Naval Sciences',
# ...

# %%
number_of_unique_values = len(df["Undergraduate Major"].unique())
print("Farklı veri sayısı:", number_of_unique_values)
# Out:
# Farklı veri sayısı: 84

# %%
df["Undergraduate Major"].value_counts()
# Out:
# Undergraduate Major
# Physics                                  35
# Aerospace Engineering                    33
# Mechanical Engineering                   30
# Aeronautical Engineering                 28
# Electrical Engineering                   23
#                                          ..
# Astronomy                                 1
# Marine Engineering & Nautical Science     1
# Philosophy                                1
# Bioscience                                1
# Military Science                          1
# Name: count, Length: 83, dtype: int64

# %%
df.groupby("Undergraduate Major")[["Space Flight (hr)"]].mean().reset_index()
# Out:
#                                   Undergraduate Major  Space Flight (hr)
# 0                                          Accounting         307.000000
# 1            Aeronautical & Astronautical Engineering         735.500000
# 2                            Aeronautical Engineering         807.250000
# 3                          Aeronautics & Astronautics         460.666667
# 4   Aeronautics & Astronautics; Earth, Atmospheric...        9159.000000
# ..                                                ...                ...
# 78                                         Psychology         218.000000
# 79                               Solid Earth Sciences         687.000000
# 80                                      Space Physics        3919.000000
# 81                                Systems Engineering        6190.000000
# 82                                            Zoology        2728.500000
#
# [83 rows x 2 columns]

# %% [markdown]
# # Gender

# %%
gender_distribution = df['Gender'].value_counts()
print("Gender distribution:\n", gender_distribution)
# Out:
# Gender distribution:
#  Gender
# Male      307
# Female     50
# Name: count, dtype: int64

# %%
df['Gender'].value_counts().plot(kind='bar')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender Distribution')
plt.show()

# %% [markdown]
# # Alma maters and majors

# %%
print("Top 5 alma maters:")
print(df['Alma Mater'].value_counts().head())
# Out:
# Top 5 alma maters:
# Alma Mater
# US Naval Academy                                  12
# US Naval Academy; US Naval Postgraduate School    11
# US Air Force Academy; Purdue University            7
# Purdue University                                  7
# MIT                                                5
# Name: count, dtype: int64

# %%
print("Top 5 undergraduate majors:")
print(df['Undergraduate Major'].value_counts().head())
# Out:
# Top 5 undergraduate majors:
# Undergraduate Major
# Physics                     35
# Aerospace Engineering       33
# Mechanical Engineering      30
# Aeronautical Engineering    28
# Electrical Engineering      23
# Name: count, dtype: int64

# %%
print("Top 5 graduate majors:")
print(df['Graduate Major'].value_counts().head())
# Out:
# Top 5 graduate majors:
# Graduate Major
# Aeronautical Engineering    27
# Aerospace Engineering       21
# Medicine                    16
# Physics                     15
# Mechanical Engineering      13
# Name: count, dtype: int64

# %% [markdown]
# # Military Background

# %%
df.head()
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired   3/3/1946     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired  5/20/1951  St. Louis, MO   Male
# 4       Buzz Aldrin  1963.0    3.0  Retired  1/20/1930  Montclair, NJ   Male
#
#                                           Alma Mater     Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...                 Geology
# 1   Montana State University; University of Colorado     Engineering Physics
# 2          US Military Academy; Princeton University             Engineering
# 3                       University of Missouri-Rolla     Applied Mathematics
# 4                           US Military Academy; MIT  Mechanical Engineering
#
# ...

# %%
print("Military rank distribution:\n", df['Military Rank'].value_counts())
# Out:
# Military rank distribution:
#  Military Rank
# Colonel                  94
# Captain                  68
# Commander                13
# Lieutenant Colonel       10
# Major                     5
# Major General             4
# Brigadier General         4
# Lieutenant Commander      3
# Lieutenant General        2
# Rear Admiral              2
# Chief Warrant Officer     1
# Vice Admiral              1
# Name: count, dtype: int64

# %%
print("Military branch distribution:\n", df['Military Branch'].value_counts())
# Out:
# Military branch distribution:
#  Military Branch
# US Air Force (Retired)             61
# US Navy (Retired)                  59
# US Air Force                       21
# US Navy                            21
# US Marine Corps (Retired)          17
# US Army (Retired)                  13
# US Army                             4
# US Air Force Reserves (Retired)     3
# US Marine Corps                     3
# US Marine Corps Reserves            2
# US Coast Guard (Retired)            2
# US Naval Reserves                   2
# US Air Force Reserves               2
# US Naval Reserves (Retired)         1
# Name: count, dtype: int64

# %% [markdown]
# # Space Experience

# %%
df.head()
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired   3/3/1946     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired  5/20/1951  St. Louis, MO   Male
# 4       Buzz Aldrin  1963.0    3.0  Retired  1/20/1930  Montclair, NJ   Male
#
#                                           Alma Mater     Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...                 Geology
# 1   Montana State University; University of Colorado     Engineering Physics
# 2          US Military Academy; Princeton University             Engineering
# 3                       University of Missouri-Rolla     Applied Mathematics
# 4                           US Military Academy; MIT  Mechanical Engineering
#
# ...

# %%
print("Ortalama uzay uçuşu sayısı:", df['Space Flights'].mean())
# Out:
# Ortalama uzay uçuşu sayısı: 2.3641456582633054

# %%
print("Ortalama uzay uçuş saatleri:", df['Space Flight (hr)'].mean())
# Out:
# Ortalama uzay uçuş saatleri: 1249.266106442577

# %%
print("Uzay yürüyüşü yapan astronot sayısı:", df['Space Walks'].sum())
# Out:
# Uzay yürüyüşü yapan astronot sayısı: 445

# %%
plt.scatter(df['Space Flight (hr)'], df['Space Walks'])
plt.xlabel('Space Flight (hr)')
plt.ylabel('Space Walks')
plt.xlim(0, 2000)
plt.ylim(0, 10)
y_values = np.arange(0, 11, 1)
plt.title('Scatter Plot of Space Flight Hours vs Space Walks')
plt.show()

# %%
print("Uzay yürüyüşlerinin ortalama süresi:", df['Space Walks (hr)'].mean())
# Out:
# Uzay yürüyüşlerinin ortalama süresi: 7.707282913165266

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Space Flights'], bins=15) 
plt.xlabel('Number of Space Flights')
plt.ylabel('Frequency')
plt.title('Histogram of Space Flights')
plt.show()

# %%
uzay_gormemis_astronotlar = df[df['Space Flights'] == 0]

print("Uzay uçuşu yapmamış astronotlar:")
print(uzay_gormemis_astronotlar)
# Out:
# Uzay uçuşu yapmamış astronotlar:
#                             Name    Year  Group      Status  Birth Date  \
# 17               Serena M. Aunon  2009.0   20.0      Active    4/9/1976
# 24        Charles A. Bassett II   1963.0    3.0    Deceased  12/30/1931
# 46                  John S. Bull  1966.0    5.0    Deceased   9/25/1934
# 50               Yvonne D. Cagle  1996.0   16.0  Management   4/24/1959
# 51             Fernando Caldeiro  1996.0   16.0    Deceased   6/12/1958
# 66             Philip K. Chapman  1967.0    6.0     Retired    3/5/1935
# 101             Jeanette J. Epps  2009.0   20.0      Active   11/3/1970
# 108              Jack D. Fischer  2009.0   20.0      Active   1/23/1974
# 116          Theodore C. Freeman  1963.0    3.0    Deceased   2/18/1930
# 129        Edward G. Givens Jr.   1966.0    5.0    Deceased    1/5/1930
# 136           Duane E. Graveline  1965.0    4.0     Retired    3/2/1931
# 165          Donald L. Holmquest  1967.0    6.0     Retired    4/7/1939
# ...

# %%
uzay_gormemis_astronotlar_sayisi = len(uzay_gormemis_astronotlar)

# %%
print("Uzay uçuşu yapmamış astronotların sayısı:", uzay_gormemis_astronotlar_sayisi)
# Out:
# Uzay uçuşu yapmamış astronotların sayısı: 23

# %% [markdown]
# # Deaths

# %%
print("Number of astronauts who died:", df['Death Date'].notnull().sum())
# Out:
# Number of astronauts who died: 52

# %%
print("Circumstances of deaths:\n", df[df['Death Date'].notnull()][['Name', 'Death Date', 'Death Mission']])
# Out:
# Circumstances of deaths:
#                              Name  Death Date          Death Mission
# 10           Michael P. Anderson    2/1/2003     STS-107 (Columbia)
# 14             Neil A. Armstrong   8/25/2012                    NaN
# 24        Charles A. Bassett II    2/28/1966                    NaN
# 36         Charles E. Brady Jr.    7/23/2006                    NaN
# 42                David M. Brown    2/1/2003     STS-107 (Columbia)
# 46                  John S. Bull   8/11/2008                    NaN
# 51             Fernando Caldeiro   10/3/2009                    NaN
# 58     Manley Lanier Carter Jr.     4/5/1991                    NaN
# 63              Roger B. Chaffee   1/27/1967               Apollo 1
# 67                Kalpana Chawla    2/1/2003     STS-107 (Columbia)
# 70               Laurel B. Clark    2/1/2003     STS-107 (Columbia)
# 78           Charles Conrad Jr.     7/8/1999                    NaN
# ...

# %% [markdown]
# 2/1/2003 tarihinde ölen üç astronot olduğunu gördüm acaba başka aynı tarihte ölen astronotlar var mı?

# %%
deaths_sorted_by_date = df[df['Death Date'].notnull()].sort_values(by='Death Date')
print("Circumstances of deaths sorted by date:\n", deaths_sorted_by_date[['Name', 'Death Date', 'Death Mission']])
# Out:
# Circumstances of deaths sorted by date:
#                              Name  Death Date          Death Mission
# 281             Mario Runco Jr.     04/23/01                    NaN
# 140            Virgil I. Grissom   1/27/1967               Apollo 1
# 341          Edward H. White II    1/27/1967               Apollo 1
# 63              Roger B. Chaffee   1/27/1967               Apollo 1
# 250           Ellison S. Onizuka   1/28/1986  STS 51-L (Challenger)
# 219         S. Christa McAuliffe   1/28/1986  STS 51-L (Challenger)
# 226             Ronald E. McNair   1/28/1986  STS 51-L (Challenger)
# 271             Judith A. Resnik   1/28/1986  STS 51-L (Challenger)
# 173            Gregory B. Jarvis   1/28/1986  STS 51-L (Challenger)
# 287            Francis R. Scobee   1/28/1986  STS 51-L (Challenger)
# 301             Michael J. Smith   1/28/1986  STS 51-L (Challenger)
# 327           Charles Lacy Veach   10/3/1995                    NaN
# ...
